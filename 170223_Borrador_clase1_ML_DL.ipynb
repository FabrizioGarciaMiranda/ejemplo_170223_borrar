# %% [markdown]
# <a href="https://colab.research.google.com/github/FabrizioGarciaMiranda/ejemplo_170223_borrar/blob/main/170223_Borrador_clase1_ML_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Este es un titulo
# ## Este es un subtitulo
# ### Este es un campo
# Texto
#
# ![MOCK-UP QUEUE TIME.png](data:image/png;base64,...)

# %%
1 + 1
# Out:
# 2
